# %% [markdown]
# https://pypi.org/project/paho-mqtt/

# %%
# !pip install paho-mqtt
# Out:
# ...
#      |████████████████████████████████| 102kB 3.9MB/s
# ...
#   Created wheel for paho-mqtt: filename=paho_mqtt-1.5.1-cp37-none-any.whl size=61546 sha256=b41e20965fdff877d92a766f126d09f897b1d9bdfc21c3e282e6472f08fa156f
#   Stored in directory: /root/.cache/pip/wheels/75/e2/f5/78942b19b4d135605e58dfe85fba52253b14d636aabf76904b
# Successfully built paho-mqtt
# ...

# %%
import paho.mqtt.client as mqtt

import json

data = []

# The callback for when the client receives a CONNACK response from the server.
def on_connect(client, userdata, flags, rc):
    print("Connected with result code "+str(rc))

    # Subscribing in on_connect() means that if we lose the connection and
    # reconnect then subscriptions will be renewed.
    client.subscribe("16153060/status") #good

# The callback for when a PUBLISH message is received from the server.
def on_message(client, userdata, msg):
    #print(msg.topic+" "+str(msg.payload))

    data.append(json.loads(msg.payload))
    print(data)


client = mqtt.Client()
client.on_connect = on_connect
client.on_message = on_message

client.connect("broker.mqtt-dashboard.com", 1883, 60)

# Blocking call that processes network traffic, dispatches callbacks and
# handles reconnecting.
# Other loop*() functions are available that give a threaded interface and a
# manual interface.
client.loop_forever()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
data = [{'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '263608', 'internal_temperature': '37.78', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.22', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.22', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.22', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-41', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-41', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '263600', 'internal_temperature': '37.22', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.22', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.22', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-35', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '38.33', 'wifi_level': '-36', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '263600', 'internal_temperature': '37.22', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '263604', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.22', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.22', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '263604', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.22', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '263600', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '262016', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '263604', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-36', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '263608', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '38.33', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '263608', 'internal_temperature': '37.22', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '263472', 'internal_temperature': '38.33', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-34', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-36', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '263608', 'internal_temperature': '37.78', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-36', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-36', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.22', 'wifi_level': '-36', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-36', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.22', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.22', 'wifi_level': '-36', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-36', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '263600', 'internal_temperature': '38.33', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-44', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '264880', 'internal_temperature': '37.78', 'wifi_level': '-43', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-36', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.22', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-36', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '263608', 'internal_temperature': '37.78', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.22', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.22', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.22', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.22', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '263604', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '263600', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-46', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-41', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265168', 'internal_temperature': '37.22', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-36', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-36', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-35', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-41', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-36', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-36', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-36', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-44', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-45', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-36', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '261768', 'internal_temperature': '37.22', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-43', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-41', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '263608', 'internal_temperature': '37.78', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-36', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-36', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '263604', 'internal_temperature': '38.33', 'wifi_level': '-49', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '38.33', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '263600', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '263604', 'internal_temperature': '38.33', 'wifi_level': '-43', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '38.33', 'wifi_level': '-43', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '263608', 'internal_temperature': '38.33', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-41', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '263408', 'internal_temperature': '38.33', 'wifi_level': '-41', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-43', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '38.33', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '263600', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '263604', 'internal_temperature': '37.78', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '263608', 'internal_temperature': '37.78', 'wifi_level': '-36', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.22', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '38.33', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.22', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '263608', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '263604', 'internal_temperature': '37.78', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '263600', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '262008', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '263408', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '38.33', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.22', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '38.33', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265172', 'internal_temperature': '37.78', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '263608', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-41', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-42', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.22', 'wifi_level': '-42', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-41', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '263600', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '38.33', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.22', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '263608', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-41', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '263608', 'internal_temperature': '38.33', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '38.33', 'wifi_level': '-41', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.22', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '263608', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-43', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '262008', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '263604', 'internal_temperature': '37.78', 'wifi_level': '-41', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.22', 'wifi_level': '-42', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-43', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '38.33', 'wifi_level': '-43', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-42', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-42', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-41', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-42', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '263608', 'internal_temperature': '38.33', 'wifi_level': '-41', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-41', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-41', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '38.33', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '263600', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '38.33', 'wifi_level': '-41', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-41', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-42', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-41', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-41', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '38.33', 'wifi_level': '-41', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '262008', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '262008', 'internal_temperature': '38.33', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '38.33', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '263608', 'internal_temperature': '38.33', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '38.33', 'wifi_level': '-41', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '263600', 'internal_temperature': '38.33', 'wifi_level': '-41', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '263604', 'internal_temperature': '37.78', 'wifi_level': '-41', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '262008', 'internal_temperature': '37.78', 'wifi_level': '-41', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '262008', 'internal_temperature': '37.78', 'wifi_level': '-41', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-41', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-41', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '263608', 'internal_temperature': '38.33', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-41', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-41', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '38.33', 'wifi_level': '-42', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-41', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-42', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '263488', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '38.33', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '38.33', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-41', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-41', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-41', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-42', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '261900', 'internal_temperature': '38.33', 'wifi_level': '-42', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '38.33', 'wifi_level': '-41', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-41', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-41', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '38.33', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '263600', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '38.33', 'wifi_level': '-41', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '263608', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '263604', 'internal_temperature': '38.33', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '263600', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-43', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-41', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '263608', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.22', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '38.33', 'wifi_level': '-41', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182776', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.22', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '263608', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '262016', 'internal_temperature': '38.33', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '263604', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '38.33', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-37', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-45', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-41', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-48', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-47', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-47', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '38.33', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '263600', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '263604', 'internal_temperature': '37.78', 'wifi_level': '-42', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-42', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '38.33', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-41', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '263608', 'internal_temperature': '38.33', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-41', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-41', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '38.33', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-41', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '263608', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '38.33', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '38.33', 'wifi_level': '-41', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '263608', 'internal_temperature': '38.33', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '262016', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '263604', 'internal_temperature': '37.78', 'wifi_level': '-38', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '263488', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '263608', 'internal_temperature': '38.33', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-42', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-42', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '38.33', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-39', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}, {'chipid': '16153060', 'minfreeheap': '182772', 'freeheap': '265196', 'internal_temperature': '37.78', 'wifi_level': '-40', 'reset_reason1': '1', 'reset_reason2': '14'}]

# %%
import pandas as pd

df = pd.json_normalize(data)

# %%
df
# Out:
#        chipid minfreeheap freeheap  ... wifi_level reset_reason1 reset_reason2
# 0    16153060      182776   265196  ...        -37             1            14
# 1    16153060      182776   265196  ...        -37             1            14
# 2    16153060      182776   265196  ...        -38             1            14
# 3    16153060      182776   263608  ...        -37             1            14
# 4    16153060      182776   265196  ...        -37             1            14
# ..        ...         ...      ...  ...        ...           ...           ...
# 531  16153060      182772   265196  ...        -39             1            14
# 532  16153060      182772   265196  ...        -39             1            14
# 533  16153060      182772   265196  ...        -40             1            14
# 534  16153060      182772   265196  ...        -40             1            14
# 535  16153060      182772   265196  ...        -40             1            14
#
# [536 rows x 7 columns]

# %%
df.to_csv("/content/drive/Shareddrives/Grupo 4 SSC-5972/Checkpoint 1/Códigos Python/good.csv", index=False)
